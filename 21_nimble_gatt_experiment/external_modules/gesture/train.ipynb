# %% [markdown]
# ##### 01 数据集导入，创建训练集和测试集。通过查看注释，理解整个流程。

# %%
import glob
import numpy as np
# 训练集、测试集划分
from sklearn.model_selection import train_test_split
# 数据集相对路径
DATA_PATH = "../../../10_tingml_datasets/"
# LABELS 的内容尽量与前面store_data.py保持一致
LABELS = ["Stationary", "Tilted", "Rotating", "MovingX", "MovingY", "MovingZ"]
# 代表一个样本内容，如连续10次传感器读到的6轴数据作为一个样本
SAMPLES_PER_GESTURE = 10
def load_one_label_data(label):
    path = DATA_PATH + label + "*.npy"
    files = glob.glob(path)
    datas = []
    for file in files:
        try:
            data = np.load(file)
            # 切除多余数据，如数据当中有61份，但每个样本只需要10份，那么最后一份需要丢弃。
            num_slice = len(data) // SAMPLES_PER_GESTURE
            datas.append(data[: num_slice * SAMPLES_PER_GESTURE, :])
        except Exception as e:
            print(e)
    datas = np.concatenate(datas, axis=0)
    # 由于本案例给的是全连接层，输入为1维数据。(其余如conv需要自行根据模型输入修改尺寸，如二维)
    # MLP
    # datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE,),)  # Modified here
    # CNN 1
    datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE, 1),)  # Modified here
    idx = LABELS.index(label)
    labels = np.ones(datas.shape[0]) * idx
    return datas, labels
all_datas = []
all_labels = []
# 导入每个label对应的数据
for label in LABELS:
    datas, labels = load_one_label_data(label)
    all_datas.append(datas)
    all_labels.append(labels)
dataX = np.concatenate(all_datas, axis=0)
dataY = np.concatenate(all_labels, axis=0)
# 输入和样本到此创建完毕

# 训练集、测试集划分
# test_size 表示数据集里面有20%将划分给测试集
# stratify=dataY指定按label进行划分, 确保数据集划分公平
xTrain, xTest, yTrain, yTest = train_test_split(
    dataX, dataY, test_size=0.2, stratify=dataY
)
print(xTrain.shape, xTest.shape, yTrain.shape, yTest.shape)
# Out:
# (2608, 60, 1) (652, 60, 1) (2608,) (652,)

# %% [markdown]
# ##### 02 模型创建
# 下面将创建很简单的多层感知机模型，后续可自行定义模型结构。需要根据自身需求，自行上网查询其他模型，如CNN，切记模型不要太大，嵌入式设备大致提供32K空间供运行模型。
# 模型需要注意输入尺寸，如CNN往往多维数据，如**Conv1d 输入二维，可将输入改为(6 * SAMPLES_PER_GESTURE,1)或者(SAMPLES_PER_GESTURE, 6), 上面数据集对应尺寸也需要修改**

# %%
import os
# 0 = INFO, 1 = WARNING, 2 = ERROR, 3 = FATAL
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
import tensorflow.keras as keras

# 设置环境变量，控制日志级别
def mlp():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 第一层, 添加全连接层，输出尺寸为64，激活函数采用"relu"
    # 第一层需要制定输入大小，这里和数据集对应input_shape=(6 * SAMPLES_PER_GESTURE,)
    model.add(keras.layers.Dense(64, activation="relu", input_shape=(6 * SAMPLES_PER_GESTURE,)))
    # 添加池化层，防止模型过拟合，每次自动忘记20%的参数
    model.add(keras.layers.Dropout(0.2))
    # 最后一层，全连接层，输出尺寸对应labels数量，激活函数采用"softmax"
    # softmaxs输出的结果代表每个label的概率，如第0个代表label 0的概率
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model
def cnn():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 注意CNN与MLP的输入shape
    # 16个输出通道，3为卷积核大小
    model.add(
        keras.layers.Conv1D(
            8,3,padding="same",activation="relu",input_shape=(6 * SAMPLES_PER_GESTURE, 1),
        )
    )
    model.add(keras.layers.Conv1D(8, 3, padding="same", activation="relu"))
    model.add(keras.layers.GlobalAveragePooling1D())
    model.add(keras.layers.Dense(8, activation="relu"))
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model


model = cnn()
# 打印模型结构
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 60, 8)             32
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 60, 8)             200
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 72
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 54
# =================================================================
# Total params: 358
# Trainable params: 358
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### 03 模型训练及测试

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# 加载模型
from tensorflow.keras.models import load_model
# 测试模型性能
from sklearn.metrics import confusion_matrix
# 模型训练优化器，学习率为0.001
optimizer = keras.optimizers.Adam(lr=0.001)
# 制定模型优化器，和损失函数、评价指标
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=optimizer,
    metrics=["sparse_categorical_accuracy"],
)
# 制定保存模型的路径
filepath = "best_model.h5"
# 训练时，保存最好模型
checkpoint = ModelCheckpoint(
    filepath,
    monitor="val_sparse_categorical_accuracy",
    verbose=1,
    save_best_only=True,
    mode="max",
)
# 模型训练, 训练集，batch_size为批大小，可提高训练速度
# validation_data指明验证集，epochs表示训练迭代轮数
# verbose=1表示打印训练日志
# callbacks调用上述保存模型的方法
history = model.fit(
    xTrain,
    yTrain,
    batch_size=8,
    validation_data=(xTest, yTest),
    epochs=50,
    verbose=1,
    callbacks=[checkpoint],
)
# 至此模型训练完毕
# Out:
# Epoch 1/50
# /home/jumbo/.local/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 326/326 [==============================] - 1s 1ms/step - loss: 1.6561 - sparse_categorical_accuracy: 0.2676 - val_loss: 1.4869 - val_sparse_categorical_accuracy: 0.4141
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.41411, saving model to best_model.h5
# Epoch 2/50
# 326/326 [==============================] - 0s 858us/step - loss: 1.4620 - sparse_categorical_accuracy: 0.4574 - val_loss: 1.3249 - val_sparse_categorical_accuracy: 0.5844
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.41411 to 0.58436, saving model to best_model.h5
# Epoch 3/50
# 326/326 [==============================] - 0s 1ms/step - loss: 1.3310 - sparse_categorical_accuracy: 0.5058 - val_loss: 1.1827 - val_sparse_categorical_accuracy: 0.5598
#
# Epoch 00003: val_sparse_categorical_accuracy did not improve from 0.58436
# Epoch 4/50
# 326/326 [==============================] - 0s 1ms/step - loss: 1.2222 - sparse_categorical_accuracy: 0.5004 - val_loss: 1.0911 - val_sparse_categorical_accuracy: 0.5690
#
# Epoch 00004: val_sparse_categorical_accuracy did not improve from 0.58436
# Epoch 5/50
# 326/326 [==============================] - 0s 1ms/step - loss: 1.1464 - sparse_categorical_accuracy: 0.5460 - val_loss: 1.0002 - val_sparse_categorical_accuracy: 0.6948
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.58436 to 0.69479, saving model to best_model.h5
# Epoch 6/50
# 326/326 [==============================] - 0s 985us/step - loss: 1.0758 - sparse_categorical_accuracy: 0.6005 - val_loss: 0.9247 - val_sparse_categorical_accuracy: 0.7193
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.69479 to 0.71933, saving model to best_model.h5
# Epoch 7/50
# 326/326 [==============================] - 0s 1ms/step - loss: 1.0209 - sparse_categorical_accuracy: 0.6043 - val_loss: 0.8715 - val_sparse_categorical_accuracy: 0.7546
#
# Epoch 00007: val_sparse_categorical_accuracy improved from 0.71933 to 0.75460, saving model to best_model.h5
# Epoch 8/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.9843 - sparse_categorical_accuracy: 0.6143 - val_loss: 0.7962 - val_sparse_categorical_accuracy: 0.7715
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.75460 to 0.77147, saving model to best_model.h5
# Epoch 9/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.9194 - sparse_categorical_accuracy: 0.6380 - val_loss: 0.7457 - val_sparse_categorical_accuracy: 0.7500
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 10/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.8991 - sparse_categorical_accuracy: 0.6411 - val_loss: 0.7114 - val_sparse_categorical_accuracy: 0.7638
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 11/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.8743 - sparse_categorical_accuracy: 0.6430 - val_loss: 0.6925 - val_sparse_categorical_accuracy: 0.7592
#
# Epoch 00011: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 12/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.8564 - sparse_categorical_accuracy: 0.6507 - val_loss: 0.6664 - val_sparse_categorical_accuracy: 0.7638
#
# Epoch 00012: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 13/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.8351 - sparse_categorical_accuracy: 0.6561 - val_loss: 0.6447 - val_sparse_categorical_accuracy: 0.7699
#
# Epoch 00013: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 14/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.8254 - sparse_categorical_accuracy: 0.6530 - val_loss: 0.6451 - val_sparse_categorical_accuracy: 0.7423
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 15/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7958 - sparse_categorical_accuracy: 0.6741 - val_loss: 0.6358 - val_sparse_categorical_accuracy: 0.7715
#
# Epoch 00015: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 16/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7835 - sparse_categorical_accuracy: 0.6702 - val_loss: 0.6130 - val_sparse_categorical_accuracy: 0.7699
#
# Epoch 00016: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 17/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7794 - sparse_categorical_accuracy: 0.6706 - val_loss: 0.6264 - val_sparse_categorical_accuracy: 0.7653
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 18/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7727 - sparse_categorical_accuracy: 0.6848 - val_loss: 0.5796 - val_sparse_categorical_accuracy: 0.7653
#
# Epoch 00018: val_sparse_categorical_accuracy did not improve from 0.77147
# Epoch 19/50
# 326/326 [==============================] - 0s 997us/step - loss: 0.7597 - sparse_categorical_accuracy: 0.6729 - val_loss: 0.5736 - val_sparse_categorical_accuracy: 0.7837
#
# Epoch 00019: val_sparse_categorical_accuracy improved from 0.77147 to 0.78374, saving model to best_model.h5
# Epoch 20/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7599 - sparse_categorical_accuracy: 0.6810 - val_loss: 0.5936 - val_sparse_categorical_accuracy: 0.7531
#
# Epoch 00020: val_sparse_categorical_accuracy did not improve from 0.78374
# Epoch 21/50
# 326/326 [==============================] - 0s 942us/step - loss: 0.7581 - sparse_categorical_accuracy: 0.6748 - val_loss: 0.5733 - val_sparse_categorical_accuracy: 0.7715
#
# Epoch 00021: val_sparse_categorical_accuracy did not improve from 0.78374
# Epoch 22/50
# 326/326 [==============================] - 0s 976us/step - loss: 0.7411 - sparse_categorical_accuracy: 0.6837 - val_loss: 0.5473 - val_sparse_categorical_accuracy: 0.7899
#
# Epoch 00022: val_sparse_categorical_accuracy improved from 0.78374 to 0.78988, saving model to best_model.h5
# Epoch 23/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7367 - sparse_categorical_accuracy: 0.6860 - val_loss: 0.5721 - val_sparse_categorical_accuracy: 0.7791
#
# Epoch 00023: val_sparse_categorical_accuracy did not improve from 0.78988
# Epoch 24/50
# 326/326 [==============================] - 0s 859us/step - loss: 0.7392 - sparse_categorical_accuracy: 0.6906 - val_loss: 0.5543 - val_sparse_categorical_accuracy: 0.7837
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.78988
# Epoch 25/50
# 326/326 [==============================] - 1s 2ms/step - loss: 0.7114 - sparse_categorical_accuracy: 0.6975 - val_loss: 0.5482 - val_sparse_categorical_accuracy: 0.7776
#
# Epoch 00025: val_sparse_categorical_accuracy did not improve from 0.78988
# Epoch 26/50
# 326/326 [==============================] - 1s 2ms/step - loss: 0.7210 - sparse_categorical_accuracy: 0.7013 - val_loss: 0.5392 - val_sparse_categorical_accuracy: 0.7822
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.78988
# Epoch 27/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7142 - sparse_categorical_accuracy: 0.6979 - val_loss: 0.5461 - val_sparse_categorical_accuracy: 0.7776
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.78988
# Epoch 28/50
# 326/326 [==============================] - 1s 2ms/step - loss: 0.6950 - sparse_categorical_accuracy: 0.6986 - val_loss: 0.5412 - val_sparse_categorical_accuracy: 0.7776
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.78988
# Epoch 29/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6877 - sparse_categorical_accuracy: 0.7074 - val_loss: 0.5872 - val_sparse_categorical_accuracy: 0.7577
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.78988
# Epoch 30/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.7028 - sparse_categorical_accuracy: 0.7036 - val_loss: 0.5338 - val_sparse_categorical_accuracy: 0.8021
#
# Epoch 00030: val_sparse_categorical_accuracy improved from 0.78988 to 0.80215, saving model to best_model.h5
# Epoch 31/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6912 - sparse_categorical_accuracy: 0.7117 - val_loss: 0.5291 - val_sparse_categorical_accuracy: 0.7807
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.80215
# Epoch 32/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6810 - sparse_categorical_accuracy: 0.7105 - val_loss: 0.5296 - val_sparse_categorical_accuracy: 0.8098
#
# Epoch 00032: val_sparse_categorical_accuracy improved from 0.80215 to 0.80982, saving model to best_model.h5
# Epoch 33/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6790 - sparse_categorical_accuracy: 0.7143 - val_loss: 0.5230 - val_sparse_categorical_accuracy: 0.7929
#
# Epoch 00033: val_sparse_categorical_accuracy did not improve from 0.80982
# Epoch 34/50
# 326/326 [==============================] - 0s 914us/step - loss: 0.6645 - sparse_categorical_accuracy: 0.7216 - val_loss: 0.5172 - val_sparse_categorical_accuracy: 0.7975
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.80982
# Epoch 35/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6778 - sparse_categorical_accuracy: 0.7078 - val_loss: 0.5233 - val_sparse_categorical_accuracy: 0.8052
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.80982
# Epoch 36/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6794 - sparse_categorical_accuracy: 0.7067 - val_loss: 0.5263 - val_sparse_categorical_accuracy: 0.7945
#
# Epoch 00036: val_sparse_categorical_accuracy did not improve from 0.80982
# Epoch 37/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6734 - sparse_categorical_accuracy: 0.7109 - val_loss: 0.5249 - val_sparse_categorical_accuracy: 0.7914
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.80982
# Epoch 38/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6732 - sparse_categorical_accuracy: 0.7086 - val_loss: 0.5170 - val_sparse_categorical_accuracy: 0.7914
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.80982
# Epoch 39/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6739 - sparse_categorical_accuracy: 0.7025 - val_loss: 0.5006 - val_sparse_categorical_accuracy: 0.8083
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.80982
# Epoch 40/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6524 - sparse_categorical_accuracy: 0.7281 - val_loss: 0.5131 - val_sparse_categorical_accuracy: 0.8175
#
# Epoch 00040: val_sparse_categorical_accuracy improved from 0.80982 to 0.81748, saving model to best_model.h5
# Epoch 41/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6580 - sparse_categorical_accuracy: 0.7163 - val_loss: 0.5023 - val_sparse_categorical_accuracy: 0.7991
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.81748
# Epoch 42/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6815 - sparse_categorical_accuracy: 0.7074 - val_loss: 0.5031 - val_sparse_categorical_accuracy: 0.8175
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.81748
# Epoch 43/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6625 - sparse_categorical_accuracy: 0.7120 - val_loss: 0.5109 - val_sparse_categorical_accuracy: 0.7960
#
# Epoch 00043: val_sparse_categorical_accuracy did not improve from 0.81748
# Epoch 44/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6752 - sparse_categorical_accuracy: 0.6940 - val_loss: 0.4923 - val_sparse_categorical_accuracy: 0.8160
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.81748
# Epoch 45/50
# 326/326 [==============================] - 0s 933us/step - loss: 0.6539 - sparse_categorical_accuracy: 0.7143 - val_loss: 0.4861 - val_sparse_categorical_accuracy: 0.8160
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.81748
# Epoch 46/50
# 326/326 [==============================] - 0s 976us/step - loss: 0.6348 - sparse_categorical_accuracy: 0.7331 - val_loss: 0.4922 - val_sparse_categorical_accuracy: 0.8006
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.81748
# Epoch 47/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6407 - sparse_categorical_accuracy: 0.7243 - val_loss: 0.4995 - val_sparse_categorical_accuracy: 0.8144
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.81748
# Epoch 48/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6249 - sparse_categorical_accuracy: 0.7274 - val_loss: 0.4768 - val_sparse_categorical_accuracy: 0.8206
#
# Epoch 00048: val_sparse_categorical_accuracy improved from 0.81748 to 0.82055, saving model to best_model.h5
# Epoch 49/50
# 326/326 [==============================] - 1s 2ms/step - loss: 0.6160 - sparse_categorical_accuracy: 0.7297 - val_loss: 0.4791 - val_sparse_categorical_accuracy: 0.8098
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.82055
# Epoch 50/50
# 326/326 [==============================] - 0s 1ms/step - loss: 0.6155 - sparse_categorical_accuracy: 0.7343 - val_loss: 0.4728 - val_sparse_categorical_accuracy: 0.8206
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.82055

# %%
# 加载模型
model = load_model(filepath)
# 模型推理，预测
predictions = model.predict(xTest)
predictions = np.argmax(predictions, axis=1)
# 查看混淆矩阵，效果越好，预测则集中在对角线。
cm = confusion_matrix(yTest, predictions)
print(cm)
# Out:
# [[122   0   0   0   6   0]
#  [  0 112   0   0   0   0]
#  [  0   0  57   8   2  17]
#  [  0   0   1 107  12   0]
#  [  6   0   0  40  66   0]
#  [  3   0  18   2   2  71]]

# %% [markdown]
# 由于运动状态简单，上述最简单的模型可能也会获得不错的性能，当运动状态变得复杂，上述MLP模型性能将很难满足需求。
# #### 04 生成最终部署的模型
# 由于RIOT系统使用的时tflite-micro库且资源有限，将模型量化，并保存成tflite-micro可识别的格式，注意
# `data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))`后的尺寸维度和大小需要和前面大致对应

# %%
# Convert the model to the TensorFlow Lite format with quantization
# 加载模型
model = load_model(filepath)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# 保存初始版本，后续对比用
open("model_basic.tflite", "wb").write(tflite_model)

# 量化模型, 定义输入格式与大小，只需要修改(-1, 6 * SAMPLES_PER_GESTURE,)与上面对应即可，其余不用变
data_test = xTest.astype("float32")
# np.reshape 和一开始数据集导入对应
# MLP
# data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))
# CNN 1
data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, 1))
data_ds = tf.data.Dataset.from_tensor_slices((data_test)).batch(1)
# Rest of your code...
def representative_data_gen():
    for input_value in data_ds.take(100):
        yield [input_value]
converter.representative_dataset = representative_data_gen
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)

# 量化前后对比
basic_model_size = os.path.getsize("model_basic.tflite")
print("Basic model is %d bytes" % basic_model_size)
quantized_model_size = os.path.getsize("model.tflite")
print("Quantized model is %d bytes" % quantized_model_size)
difference = basic_model_size - quantized_model_size
print("Difference is %d bytes" % difference)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmpe8p7e6_t/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmpiakfxzju/assets
# INFO:tensorflow:Assets written to: /tmp/tmpiakfxzju/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# Basic model is 5328 bytes
# Quantized model is 5616 bytes
# Difference is -288 bytes
# fully_quantize: 0, inference_type: 6, input_inference_type: 0, output_inference_type: 0

# %% [markdown]
# 前面，通过量化，帮助我们模型节省了2440Bytes大小。需要验证量化后的模型输入格式和尺寸是否正确

# %%
# Now let's verify the model on a few input digits
# Instantiate an interpreter for the model
model_quantized_reloaded = tf.lite.Interpreter("model.tflite")

# Allocate memory for each model
model_quantized_reloaded.allocate_tensors()

# Get the input and output tensors so we can feed in values and get the results
model_quantized_input = model_quantized_reloaded.get_input_details()[0]["index"]
model_quantized_output = model_quantized_reloaded.get_output_details()[0]["index"]
# Create arrays to store the results
model_quantized_predictions = np.empty(xTest.size)
for i in range(20):
    # Reshape the data and ensure the type is float32
    # test_data = np.reshape(
    #     xTest[i],
    #     (
    #         1,
    #         6 * SAMPLES_PER_GESTURE,
    #         1,
    #     ),
    # ).astype("float32")
    test_data = np.expand_dims(xTest[i], axis=0).astype("float32")
    print(test_data.shape)
    # Invoke the interpreter
    model_quantized_reloaded.set_tensor(model_quantized_input, test_data)
    model_quantized_reloaded.invoke()
    model_quantized_prediction = model_quantized_reloaded.get_tensor(
        model_quantized_output
    )

    print("Digit: {} - Prediction:\n{}".format(yTest[i], model_quantized_prediction))
    print("")
# Out:
# (1, 60, 1)
# Digit: 4.0 - Prediction:
# [[0.48046875 0.         0.00390625 0.01953125 0.48046875 0.01953125]]
#
# (1, 60, 1)
# Digit: 5.0 - Prediction:
# [[0.         0.         0.48828125 0.00390625 0.01953125 0.48828125]]
#
# (1, 60, 1)
# Digit: 5.0 - Prediction:
# [[0.        0.        0.1640625 0.        0.        0.8359375]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.1640625 0.8359375 0.        0.        0.        0.       ]]
#
# (1, 60, 1)
# Digit: 4.0 - Prediction:
# [[0.29296875 0.         0.05859375 0.29296875 0.29296875 0.05859375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.  0.  0.5 0.  0.  0.5]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.03125    0.78515625 0.15625    0.03125   ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.         0.99609375 0.         0.         0.         0.        ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.0078125 0.828125  0.        0.        0.1640625 0.       ]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.  0.  0.5 0.  0.  0.5]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.        0.        0.0390625 0.        0.        0.9609375]]
#
# (1, 60, 1)
# Digit: 4.0 - Prediction:
# [[0.48828125 0.         0.00390625 0.00390625 0.48828125 0.01953125]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.03125    0.78515625 0.15625    0.03125   ]]
#
# (1, 60, 1)
# Digit: 5.0 - Prediction:
# [[0.29296875 0.         0.05859375 0.29296875 0.29296875 0.05859375]]
#
# (1, 60, 1)
# Digit: 2.0 - Prediction:
# [[0.  0.  0.5 0.  0.  0.5]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.1640625 0.8359375 0.        0.        0.        0.       ]]
#
# (1, 60, 1)
# Digit: 1.0 - Prediction:
# [[0.        0.9921875 0.        0.        0.0078125 0.       ]]
#
# (1, 60, 1)
# Digit: 4.0 - Prediction:
# [[0.         0.         0.03125    0.78515625 0.15625    0.03125   ]]
#
# (1, 60, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.01953125 0.48046875 0.48046875 0.01953125]]
#
# (1, 60, 1)
# Digit: 0.0 - Prediction:
# [[0.953125   0.         0.         0.         0.03515625 0.0078125 ]]
