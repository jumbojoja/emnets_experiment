# %% [markdown]
# ##### 01 数据集导入，创建训练集和测试集。通过查看注释，理解整个流程。

# %%
import glob
import numpy as np
# 训练集、测试集划分
from sklearn.model_selection import train_test_split
# 数据集相对路径
DATA_PATH = "../../../10_tingml_datasets/"
# LABELS 的内容尽量与前面store_data.py保持一致
LABELS = ["Stationary", "Tilted", "Rotating", "MovingX", "MovingY", "MovingZ"]
# 代表一个样本内容，如连续10次传感器读到的6轴数据作为一个样本
SAMPLES_PER_GESTURE = 10
def load_one_label_data(label):
    path = DATA_PATH + label + "*.npy"
    files = glob.glob(path)
    datas = []
    for file in files:
        try:
            data = np.load(file)
            # 切除多余数据，如数据当中有61份，但每个样本只需要10份，那么最后一份需要丢弃。
            num_slice = len(data) // SAMPLES_PER_GESTURE
            datas.append(data[: num_slice * SAMPLES_PER_GESTURE, :])
        except Exception as e:
            print(e)
    datas = np.concatenate(datas, axis=0)
    # 由于本案例给的是全连接层，输入为1维数据。(其余如conv需要自行根据模型输入修改尺寸，如二维)
    # MLP
    # datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE,),)  # Modified here
    # CNN 1
    datas = np.reshape(datas,(-1, 6 * SAMPLES_PER_GESTURE, 1),)  # Modified here
    idx = LABELS.index(label)
    labels = np.ones(datas.shape[0]) * idx
    return datas, labels
all_datas = []
all_labels = []
# 导入每个label对应的数据
for label in LABELS:
    datas, labels = load_one_label_data(label)
    all_datas.append(datas)
    all_labels.append(labels)
dataX = np.concatenate(all_datas, axis=0)
dataY = np.concatenate(all_labels, axis=0)
# 输入和样本到此创建完毕

# 训练集、测试集划分
# test_size 表示数据集里面有20%将划分给测试集
# stratify=dataY指定按label进行划分, 确保数据集划分公平
xTrain, xTest, yTrain, yTest = train_test_split(
    dataX, dataY, test_size=0.2, stratify=dataY
)
print(xTrain.shape, xTest.shape, yTrain.shape, yTest.shape)
# Out:
# (1820, 90, 1) (455, 90, 1) (1820,) (455,)

# %% [markdown]
# ##### 02 模型创建
# 下面将创建很简单的多层感知机模型，后续可自行定义模型结构。需要根据自身需求，自行上网查询其他模型，如CNN，切记模型不要太大，嵌入式设备大致提供32K空间供运行模型。
# 模型需要注意输入尺寸，如CNN往往多维数据，如**Conv1d 输入二维，可将输入改为(6 * SAMPLES_PER_GESTURE,1)或者(SAMPLES_PER_GESTURE, 6), 上面数据集对应尺寸也需要修改**

# %%
import os
# 0 = INFO, 1 = WARNING, 2 = ERROR, 3 = FATAL
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import tensorflow as tf
import tensorflow.keras as keras

# 设置环境变量，控制日志级别
def mlp():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 第一层, 添加全连接层，输出尺寸为64，激活函数采用"relu"
    # 第一层需要制定输入大小，这里和数据集对应input_shape=(6 * SAMPLES_PER_GESTURE,)
    model.add(keras.layers.Dense(64, activation="relu", input_shape=(6 * SAMPLES_PER_GESTURE,)))
    # 添加池化层，防止模型过拟合，每次自动忘记20%的参数
    model.add(keras.layers.Dropout(0.2))
    # 最后一层，全连接层，输出尺寸对应labels数量，激活函数采用"softmax"
    # softmaxs输出的结果代表每个label的概率，如第0个代表label 0的概率
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model
def cnn():
    # 一个用于线性堆叠多个网络层的模型。
    # Sequential模型是最简单的神经网络模型，它按照层的顺序依次堆叠，每一层的输出会成为下一层的输入。
    model = keras.Sequential()
    # 注意CNN与MLP的输入shape
    # 16个输出通道，3为卷积核大小
    model.add(
        keras.layers.Conv1D(
            8,3,padding="same",activation="relu",input_shape=(6 * SAMPLES_PER_GESTURE, 1),
        )
    )
    model.add(keras.layers.Conv1D(8, 3, padding="same", activation="relu"))
    model.add(keras.layers.GlobalAveragePooling1D())
    model.add(keras.layers.Dense(8, activation="relu"))
    model.add(keras.layers.Dropout(0.2))
    model.add(keras.layers.Dense(len(LABELS), activation="softmax"))
    return model


model = cnn()
# 打印模型结构
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d (Conv1D)              (None, 90, 8)             32
# _________________________________________________________________
# conv1d_1 (Conv1D)            (None, 90, 8)             200
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 8)                 0
# _________________________________________________________________
# dense (Dense)                (None, 8)                 72
# _________________________________________________________________
# dropout (Dropout)            (None, 8)                 0
# _________________________________________________________________
# dense_1 (Dense)              (None, 6)                 54
# =================================================================
# Total params: 358
# Trainable params: 358
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ##### 03 模型训练及测试

# %%
from tensorflow.keras.callbacks import ModelCheckpoint
# 加载模型
from tensorflow.keras.models import load_model
# 测试模型性能
from sklearn.metrics import confusion_matrix
# 模型训练优化器，学习率为0.001
optimizer = keras.optimizers.Adam(lr=0.001)
# 制定模型优化器，和损失函数、评价指标
model.compile(
    loss="sparse_categorical_crossentropy",
    optimizer=optimizer,
    metrics=["sparse_categorical_accuracy"],
)
# 制定保存模型的路径
filepath = "best_model.h5"
# 训练时，保存最好模型
checkpoint = ModelCheckpoint(
    filepath,
    monitor="val_sparse_categorical_accuracy",
    verbose=1,
    save_best_only=True,
    mode="max",
)
# 模型训练, 训练集，batch_size为批大小，可提高训练速度
# validation_data指明验证集，epochs表示训练迭代轮数
# verbose=1表示打印训练日志
# callbacks调用上述保存模型的方法
history = model.fit(
    xTrain,
    yTrain,
    batch_size=8,
    validation_data=(xTest, yTest),
    epochs=50,
    verbose=1,
    callbacks=[checkpoint],
)
# 至此模型训练完毕
# Out:
# Epoch 1/50
# /home/jumbo/.local/lib/python3.8/site-packages/keras/optimizer_v2/optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(
# 228/228 [==============================] - 1s 1ms/step - loss: 1.7686 - sparse_categorical_accuracy: 0.1973 - val_loss: 1.6260 - val_sparse_categorical_accuracy: 0.2703
#
# Epoch 00001: val_sparse_categorical_accuracy improved from -inf to 0.27033, saving model to best_model.h5
# Epoch 2/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.5924 - sparse_categorical_accuracy: 0.3115 - val_loss: 1.4941 - val_sparse_categorical_accuracy: 0.3495
#
# Epoch 00002: val_sparse_categorical_accuracy improved from 0.27033 to 0.34945, saving model to best_model.h5
# Epoch 3/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.4908 - sparse_categorical_accuracy: 0.3291 - val_loss: 1.3910 - val_sparse_categorical_accuracy: 0.3626
#
# Epoch 00003: val_sparse_categorical_accuracy improved from 0.34945 to 0.36264, saving model to best_model.h5
# Epoch 4/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.4139 - sparse_categorical_accuracy: 0.4088 - val_loss: 1.3157 - val_sparse_categorical_accuracy: 0.5429
#
# Epoch 00004: val_sparse_categorical_accuracy improved from 0.36264 to 0.54286, saving model to best_model.h5
# Epoch 5/50
# 228/228 [==============================] - 0s 894us/step - loss: 1.3436 - sparse_categorical_accuracy: 0.4984 - val_loss: 1.2401 - val_sparse_categorical_accuracy: 0.5495
#
# Epoch 00005: val_sparse_categorical_accuracy improved from 0.54286 to 0.54945, saving model to best_model.h5
# Epoch 6/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.2875 - sparse_categorical_accuracy: 0.5099 - val_loss: 1.1908 - val_sparse_categorical_accuracy: 0.5648
#
# Epoch 00006: val_sparse_categorical_accuracy improved from 0.54945 to 0.56484, saving model to best_model.h5
# Epoch 7/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.2543 - sparse_categorical_accuracy: 0.5143 - val_loss: 1.1530 - val_sparse_categorical_accuracy: 0.5319
#
# Epoch 00007: val_sparse_categorical_accuracy did not improve from 0.56484
# Epoch 8/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.2176 - sparse_categorical_accuracy: 0.4967 - val_loss: 1.1113 - val_sparse_categorical_accuracy: 0.5802
#
# Epoch 00008: val_sparse_categorical_accuracy improved from 0.56484 to 0.58022, saving model to best_model.h5
# Epoch 9/50
# 228/228 [==============================] - 0s 845us/step - loss: 1.1710 - sparse_categorical_accuracy: 0.4984 - val_loss: 1.0599 - val_sparse_categorical_accuracy: 0.5648
#
# Epoch 00009: val_sparse_categorical_accuracy did not improve from 0.58022
# Epoch 10/50
# 228/228 [==============================] - 0s 876us/step - loss: 1.1418 - sparse_categorical_accuracy: 0.5049 - val_loss: 1.0453 - val_sparse_categorical_accuracy: 0.5516
#
# Epoch 00010: val_sparse_categorical_accuracy did not improve from 0.58022
# Epoch 11/50
# 228/228 [==============================] - 0s 809us/step - loss: 1.1243 - sparse_categorical_accuracy: 0.5016 - val_loss: 1.0190 - val_sparse_categorical_accuracy: 0.5956
#
# Epoch 00011: val_sparse_categorical_accuracy improved from 0.58022 to 0.59560, saving model to best_model.h5
# Epoch 12/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.0952 - sparse_categorical_accuracy: 0.5231 - val_loss: 1.0001 - val_sparse_categorical_accuracy: 0.6132
#
# Epoch 00012: val_sparse_categorical_accuracy improved from 0.59560 to 0.61319, saving model to best_model.h5
# Epoch 13/50
# 228/228 [==============================] - 0s 821us/step - loss: 1.0792 - sparse_categorical_accuracy: 0.5231 - val_loss: 0.9663 - val_sparse_categorical_accuracy: 0.6176
#
# Epoch 00013: val_sparse_categorical_accuracy improved from 0.61319 to 0.61758, saving model to best_model.h5
# Epoch 14/50
# 228/228 [==============================] - 0s 845us/step - loss: 1.0512 - sparse_categorical_accuracy: 0.5451 - val_loss: 0.9406 - val_sparse_categorical_accuracy: 0.6022
#
# Epoch 00014: val_sparse_categorical_accuracy did not improve from 0.61758
# Epoch 15/50
# 228/228 [==============================] - 0s 1ms/step - loss: 1.0506 - sparse_categorical_accuracy: 0.5473 - val_loss: 0.9316 - val_sparse_categorical_accuracy: 0.6857
#
# Epoch 00015: val_sparse_categorical_accuracy improved from 0.61758 to 0.68571, saving model to best_model.h5
# Epoch 16/50
# 228/228 [==============================] - 0s 827us/step - loss: 1.0121 - sparse_categorical_accuracy: 0.6176 - val_loss: 0.9086 - val_sparse_categorical_accuracy: 0.7363
#
# Epoch 00016: val_sparse_categorical_accuracy improved from 0.68571 to 0.73626, saving model to best_model.h5
# Epoch 17/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.9891 - sparse_categorical_accuracy: 0.6385 - val_loss: 0.8803 - val_sparse_categorical_accuracy: 0.7363
#
# Epoch 00017: val_sparse_categorical_accuracy did not improve from 0.73626
# Epoch 18/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.9813 - sparse_categorical_accuracy: 0.6841 - val_loss: 0.8738 - val_sparse_categorical_accuracy: 0.7714
#
# Epoch 00018: val_sparse_categorical_accuracy improved from 0.73626 to 0.77143, saving model to best_model.h5
# Epoch 19/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.9748 - sparse_categorical_accuracy: 0.6813 - val_loss: 0.8548 - val_sparse_categorical_accuracy: 0.7780
#
# Epoch 00019: val_sparse_categorical_accuracy improved from 0.77143 to 0.77802, saving model to best_model.h5
# Epoch 20/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.9424 - sparse_categorical_accuracy: 0.6786 - val_loss: 0.8279 - val_sparse_categorical_accuracy: 0.7802
#
# Epoch 00020: val_sparse_categorical_accuracy improved from 0.77802 to 0.78022, saving model to best_model.h5
# Epoch 21/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.9173 - sparse_categorical_accuracy: 0.6890 - val_loss: 0.7800 - val_sparse_categorical_accuracy: 0.7956
#
# Epoch 00021: val_sparse_categorical_accuracy improved from 0.78022 to 0.79560, saving model to best_model.h5
# Epoch 22/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.9155 - sparse_categorical_accuracy: 0.6742 - val_loss: 0.7752 - val_sparse_categorical_accuracy: 0.7890
#
# Epoch 00022: val_sparse_categorical_accuracy did not improve from 0.79560
# Epoch 23/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.8866 - sparse_categorical_accuracy: 0.6687 - val_loss: 0.7338 - val_sparse_categorical_accuracy: 0.7978
#
# Epoch 00023: val_sparse_categorical_accuracy improved from 0.79560 to 0.79780, saving model to best_model.h5
# Epoch 24/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.8607 - sparse_categorical_accuracy: 0.6978 - val_loss: 0.7737 - val_sparse_categorical_accuracy: 0.7736
#
# Epoch 00024: val_sparse_categorical_accuracy did not improve from 0.79780
# Epoch 25/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.8616 - sparse_categorical_accuracy: 0.7016 - val_loss: 0.7115 - val_sparse_categorical_accuracy: 0.8066
#
# Epoch 00025: val_sparse_categorical_accuracy improved from 0.79780 to 0.80659, saving model to best_model.h5
# Epoch 26/50
# 228/228 [==============================] - 0s 2ms/step - loss: 0.8539 - sparse_categorical_accuracy: 0.7027 - val_loss: 0.7111 - val_sparse_categorical_accuracy: 0.7868
#
# Epoch 00026: val_sparse_categorical_accuracy did not improve from 0.80659
# Epoch 27/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.8487 - sparse_categorical_accuracy: 0.6923 - val_loss: 0.6937 - val_sparse_categorical_accuracy: 0.8066
#
# Epoch 00027: val_sparse_categorical_accuracy did not improve from 0.80659
# Epoch 28/50
# 228/228 [==============================] - 0s 992us/step - loss: 0.8379 - sparse_categorical_accuracy: 0.7093 - val_loss: 0.6726 - val_sparse_categorical_accuracy: 0.8000
#
# Epoch 00028: val_sparse_categorical_accuracy did not improve from 0.80659
# Epoch 29/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.8167 - sparse_categorical_accuracy: 0.7000 - val_loss: 0.6684 - val_sparse_categorical_accuracy: 0.7890
#
# Epoch 00029: val_sparse_categorical_accuracy did not improve from 0.80659
# Epoch 30/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.8068 - sparse_categorical_accuracy: 0.7154 - val_loss: 0.6832 - val_sparse_categorical_accuracy: 0.7956
#
# Epoch 00030: val_sparse_categorical_accuracy did not improve from 0.80659
# Epoch 31/50
# 228/228 [==============================] - 0s 2ms/step - loss: 0.7838 - sparse_categorical_accuracy: 0.7110 - val_loss: 0.6424 - val_sparse_categorical_accuracy: 0.8066
#
# Epoch 00031: val_sparse_categorical_accuracy did not improve from 0.80659
# Epoch 32/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.8199 - sparse_categorical_accuracy: 0.7082 - val_loss: 0.6565 - val_sparse_categorical_accuracy: 0.8132
#
# Epoch 00032: val_sparse_categorical_accuracy improved from 0.80659 to 0.81319, saving model to best_model.h5
# Epoch 33/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7941 - sparse_categorical_accuracy: 0.7231 - val_loss: 0.6294 - val_sparse_categorical_accuracy: 0.8198
#
# Epoch 00033: val_sparse_categorical_accuracy improved from 0.81319 to 0.81978, saving model to best_model.h5
# Epoch 34/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7874 - sparse_categorical_accuracy: 0.7154 - val_loss: 0.6332 - val_sparse_categorical_accuracy: 0.8176
#
# Epoch 00034: val_sparse_categorical_accuracy did not improve from 0.81978
# Epoch 35/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7758 - sparse_categorical_accuracy: 0.7225 - val_loss: 0.6254 - val_sparse_categorical_accuracy: 0.8022
#
# Epoch 00035: val_sparse_categorical_accuracy did not improve from 0.81978
# Epoch 36/50
# 228/228 [==============================] - 0s 2ms/step - loss: 0.7717 - sparse_categorical_accuracy: 0.7209 - val_loss: 0.6094 - val_sparse_categorical_accuracy: 0.8264
#
# Epoch 00036: val_sparse_categorical_accuracy improved from 0.81978 to 0.82637, saving model to best_model.h5
# Epoch 37/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7723 - sparse_categorical_accuracy: 0.7203 - val_loss: 0.6154 - val_sparse_categorical_accuracy: 0.8242
#
# Epoch 00037: val_sparse_categorical_accuracy did not improve from 0.82637
# Epoch 38/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7564 - sparse_categorical_accuracy: 0.7302 - val_loss: 0.5991 - val_sparse_categorical_accuracy: 0.8198
#
# Epoch 00038: val_sparse_categorical_accuracy did not improve from 0.82637
# Epoch 39/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7718 - sparse_categorical_accuracy: 0.7247 - val_loss: 0.5918 - val_sparse_categorical_accuracy: 0.8198
#
# Epoch 00039: val_sparse_categorical_accuracy did not improve from 0.82637
# Epoch 40/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7535 - sparse_categorical_accuracy: 0.7225 - val_loss: 0.5846 - val_sparse_categorical_accuracy: 0.8286
#
# Epoch 00040: val_sparse_categorical_accuracy improved from 0.82637 to 0.82857, saving model to best_model.h5
# Epoch 41/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7605 - sparse_categorical_accuracy: 0.7341 - val_loss: 0.5911 - val_sparse_categorical_accuracy: 0.8110
#
# Epoch 00041: val_sparse_categorical_accuracy did not improve from 0.82857
# Epoch 42/50
# 228/228 [==============================] - 0s 2ms/step - loss: 0.7579 - sparse_categorical_accuracy: 0.7352 - val_loss: 0.5961 - val_sparse_categorical_accuracy: 0.8088
#
# Epoch 00042: val_sparse_categorical_accuracy did not improve from 0.82857
# Epoch 43/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7674 - sparse_categorical_accuracy: 0.7247 - val_loss: 0.5907 - val_sparse_categorical_accuracy: 0.8308
#
# Epoch 00043: val_sparse_categorical_accuracy improved from 0.82857 to 0.83077, saving model to best_model.h5
# Epoch 44/50
# 228/228 [==============================] - 0s 2ms/step - loss: 0.7444 - sparse_categorical_accuracy: 0.7319 - val_loss: 0.5976 - val_sparse_categorical_accuracy: 0.8066
#
# Epoch 00044: val_sparse_categorical_accuracy did not improve from 0.83077
# Epoch 45/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7484 - sparse_categorical_accuracy: 0.7275 - val_loss: 0.6074 - val_sparse_categorical_accuracy: 0.8264
#
# Epoch 00045: val_sparse_categorical_accuracy did not improve from 0.83077
# Epoch 46/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7490 - sparse_categorical_accuracy: 0.7313 - val_loss: 0.5920 - val_sparse_categorical_accuracy: 0.8132
#
# Epoch 00046: val_sparse_categorical_accuracy did not improve from 0.83077
# Epoch 47/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7363 - sparse_categorical_accuracy: 0.7374 - val_loss: 0.5773 - val_sparse_categorical_accuracy: 0.8264
#
# Epoch 00047: val_sparse_categorical_accuracy did not improve from 0.83077
# Epoch 48/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7574 - sparse_categorical_accuracy: 0.7319 - val_loss: 0.5791 - val_sparse_categorical_accuracy: 0.8264
#
# Epoch 00048: val_sparse_categorical_accuracy did not improve from 0.83077
# Epoch 49/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7462 - sparse_categorical_accuracy: 0.7291 - val_loss: 0.5805 - val_sparse_categorical_accuracy: 0.8286
#
# Epoch 00049: val_sparse_categorical_accuracy did not improve from 0.83077
# Epoch 50/50
# 228/228 [==============================] - 0s 1ms/step - loss: 0.7650 - sparse_categorical_accuracy: 0.7209 - val_loss: 0.5761 - val_sparse_categorical_accuracy: 0.8286
#
# Epoch 00050: val_sparse_categorical_accuracy did not improve from 0.83077

# %%
# 加载模型
model = load_model(filepath)
# 模型推理，预测
predictions = model.predict(xTest)
predictions = np.argmax(predictions, axis=1)
# 查看混淆矩阵，效果越好，预测则集中在对角线。
cm = confusion_matrix(yTest, predictions)
print(cm)
# Out:
# [[ 81   0   0   0   2   0]
#  [  0  73   0   0   0   0]
#  [  0   0  29   4   2  20]
#  [  0   0   1 103   5   0]
#  [  4   0   0  26  43   0]
#  [  0   0  11   2   0  49]]

# %% [markdown]
# 由于运动状态简单，上述最简单的模型可能也会获得不错的性能，当运动状态变得复杂，上述MLP模型性能将很难满足需求。
# #### 04 生成最终部署的模型
# 由于RIOT系统使用的时tflite-micro库且资源有限，将模型量化，并保存成tflite-micro可识别的格式，注意
# `data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))`后的尺寸维度和大小需要和前面大致对应

# %%
# Convert the model to the TensorFlow Lite format with quantization
# 加载模型
model = load_model(filepath)
converter = tf.lite.TFLiteConverter.from_keras_model(model)
tflite_model = converter.convert()
# 保存初始版本，后续对比用
open("model_basic.tflite", "wb").write(tflite_model)

# 量化模型, 定义输入格式与大小，只需要修改(-1, 6 * SAMPLES_PER_GESTURE,)与上面对应即可，其余不用变
data_test = xTest.astype("float32")
# np.reshape 和一开始数据集导入对应
# MLP
# data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, ))
# CNN 1
data_test = np.reshape(data_test, (-1, 6 * SAMPLES_PER_GESTURE, 1))
data_ds = tf.data.Dataset.from_tensor_slices((data_test)).batch(1)
# Rest of your code...
def representative_data_gen():
    for input_value in data_ds.take(100):
        yield [input_value]
converter.representative_dataset = representative_data_gen
converter.optimizations = [tf.lite.Optimize.OPTIMIZE_FOR_SIZE]
tflite_model = converter.convert()
open("model.tflite", "wb").write(tflite_model)

# 量化前后对比
basic_model_size = os.path.getsize("model_basic.tflite")
print("Basic model is %d bytes" % basic_model_size)
quantized_model_size = os.path.getsize("model.tflite")
print("Quantized model is %d bytes" % quantized_model_size)
difference = basic_model_size - quantized_model_size
print("Difference is %d bytes" % difference)
# Out:
# INFO:tensorflow:Assets written to: /tmp/tmp8n40hy6b/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# INFO:tensorflow:Assets written to: /tmp/tmp22p2i98_/assets
# INFO:tensorflow:Assets written to: /tmp/tmp22p2i98_/assets
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# WARNING:absl:Optimization option OPTIMIZE_FOR_SIZE is deprecated, please use optimizations=[Optimize.DEFAULT] instead.
# Basic model is 5328 bytes
# Quantized model is 5616 bytes
# Difference is -288 bytes
# fully_quantize: 0, inference_type: 6, input_inference_type: 0, output_inference_type: 0

# %% [markdown]
# 前面，通过量化，帮助我们模型节省了2440Bytes大小。需要验证量化后的模型输入格式和尺寸是否正确

# %%
# Now let's verify the model on a few input digits
# Instantiate an interpreter for the model
model_quantized_reloaded = tf.lite.Interpreter("model.tflite")

# Allocate memory for each model
model_quantized_reloaded.allocate_tensors()

# Get the input and output tensors so we can feed in values and get the results
model_quantized_input = model_quantized_reloaded.get_input_details()[0]["index"]
model_quantized_output = model_quantized_reloaded.get_output_details()[0]["index"]
# Create arrays to store the results
model_quantized_predictions = np.empty(xTest.size)
for i in range(20):
    # Reshape the data and ensure the type is float32
    # test_data = np.reshape(
    #     xTest[i],
    #     (
    #         1,
    #         6 * SAMPLES_PER_GESTURE,
    #         1,
    #     ),
    # ).astype("float32")
    test_data = np.expand_dims(xTest[i], axis=0).astype("float32")
    print(test_data.shape)
    # Invoke the interpreter
    model_quantized_reloaded.set_tensor(model_quantized_input, test_data)
    model_quantized_reloaded.invoke()
    model_quantized_prediction = model_quantized_reloaded.get_tensor(
        model_quantized_output
    )

    print("Digit: {} - Prediction:\n{}".format(yTest[i], model_quantized_prediction))
    print("")
# Out:
# (1, 90, 1)
# Digit: 4.0 - Prediction:
# [[0.0625     0.         0.0625     0.19921875 0.65625    0.01953125]]
#
# (1, 90, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.890625   0.02734375 0.0078125  0.02734375 0.02734375]]
#
# (1, 90, 1)
# Digit: 0.0 - Prediction:
# [[0.20703125 0.68359375 0.0078125  0.01953125 0.0625     0.01953125]]
#
# (1, 90, 1)
# Digit: 5.0 - Prediction:
# [[0.        0.        0.0859375 0.        0.        0.9140625]]
#
# (1, 90, 1)
# Digit: 5.0 - Prediction:
# [[0.        0.        0.0859375 0.        0.        0.9140625]]
#
# (1, 90, 1)
# Digit: 0.0 - Prediction:
# [[0.546875   0.05078125 0.015625   0.16796875 0.16796875 0.05078125]]
#
# (1, 90, 1)
# Digit: 1.0 - Prediction:
# [[0.1875     0.6171875  0.01953125 0.05859375 0.05859375 0.05859375]]
#
# (1, 90, 1)
# Digit: 2.0 - Prediction:
# [[0.       0.       0.234375 0.       0.       0.765625]]
#
# (1, 90, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.04296875 0.47265625 0.47265625 0.01171875]]
#
# (1, 90, 1)
# Digit: 4.0 - Prediction:
# [[0.11328125 0.         0.11328125 0.37109375 0.37109375 0.03515625]]
#
# (1, 90, 1)
# Digit: 5.0 - Prediction:
# [[0.       0.       0.234375 0.       0.       0.765625]]
#
# (1, 90, 1)
# Digit: 5.0 - Prediction:
# [[0.       0.       0.234375 0.       0.       0.765625]]
#
# (1, 90, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.765625   0.         0.00390625 0.234375  ]]
#
# (1, 90, 1)
# Digit: 4.0 - Prediction:
# [[0.         0.         0.04296875 0.46875    0.46875    0.01171875]]
#
# (1, 90, 1)
# Digit: 5.0 - Prediction:
# [[0.  0.  0.5 0.  0.  0.5]]
#
# (1, 90, 1)
# Digit: 0.0 - Prediction:
# [[0.33203125 0.1015625  0.03125    0.1015625  0.33203125 0.1015625 ]]
#
# (1, 90, 1)
# Digit: 1.0 - Prediction:
# [[0.0078125  0.8125     0.07421875 0.0078125  0.0234375  0.07421875]]
#
# (1, 90, 1)
# Digit: 3.0 - Prediction:
# [[0.         0.         0.1328125  0.4296875  0.4296875  0.01171875]]
#
# (1, 90, 1)
# Digit: 2.0 - Prediction:
# [[0.         0.         0.90625    0.00390625 0.0078125  0.0859375 ]]
#
# (1, 90, 1)
# Digit: 1.0 - Prediction:
# [[0.02734375 0.890625   0.02734375 0.0078125  0.02734375 0.02734375]]
